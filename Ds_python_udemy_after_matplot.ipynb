# %% [markdown]
# <a href="https://colab.research.google.com/github/rb7488/Python-Library-/blob/main/Ds_python_udemy_after_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, we study the cocept after the data analysis in python using Matplot,Seaborn

# %% [markdown]
# Logging in python

# %%
import logging

#configure the basic logging setting
logging.basicConfig(level=logging.DEBUG)

## logging message with different severity level
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
#multithreading
import threading
import time
#take the notes from udemy notes on github

# %%
import multiprocessing
import time
def sq_number():
    for i in range(5):
     time.sleep(1)
     print(f"Square: {i*i}")
def cube_number():
    for i in range(5):
     time.sleep(1.5)
     print(f"Cube :{i*i*i}")
if __name__=="__main__":

 #create two process (p1 = ek naya process jo sq_number() run karega,

# p2 = ek alag process jo cube_number() run karega,dono diff process,diff memory,OS scheule this)


    p1=multiprocessing.Process(target=sq_number)
    p2=multiprocessing.Process(target=cube_number)
    t=time.time()
    #start the process(dono kaam saath chalao, parallel execution start hota hai.)
    p1.start()
    p2.start()
    #waiting for the process to complete(jab tk p1,p2 complete n ho jye)
    p1.join()
    p2.join()
# Out:
# Square: 0
# Cube :0
# Square: 1
# Cube :1
# Square: 4
# Square: 9
# Cube :8
# Square: 16
# Cube :27
# Cube :64

# %%
#multiple threading with threadpool executor
from concurrent.futures import ThreadPoolExecutor
import time
def print_num(num):
    time.sleep(1)
    return f"number:{num}"
num=[1,2,3,4,5,6]
with ThreadPoolExecutor(max_workers=3) as executor:
    results=executor.map(print_num,num)
    for result in results:
        print(result)
# Out:
# number:1
# number:2
# number:3
# number:4
# number:5
# number:6

# %%
#multiple process with processpool executor
from concurrent.futures import ProcessPoolExecutor
import time
def sq_num(num):
    time.sleep(1)
    return f"number:{num*num}"
num=[1,2,3,4,5,6]
with ProcessPoolExecutor(max_workers=3) as executor:
    results=executor.map(sq_num,num)
    for result in results:
        print(result)
# Out:
# number:1
# number:4
# number:9
# number:16
# number:25
# number:36

# %%
''' web page scrapping using threading (see the notes of udemy lecture)'''

# %% [markdown]
# Memory management in python

# %%
import sys
a=[]
#here a is taken one spaces and getref function is also get 1 spaces
print(sys.getrefcount(a))
# Out:
# 2

# %%
b=a
print(sys.getrefcount(a))
#here a,b,getref func get 1 spaces each
# Out:
# 3

# %%
del b
print(sys.getrefcount(a))
# Out:
# 2

# %%
#Garbage Collection
import gc
#enable garbage collection
gc.enable()

# %%
gc.disable()

# %%
gc.collect()
# Out:
# 0

# %%
#garbage collection stats
print(gc.get_stats())
# Out:
# [{'collections': 248, 'collected': 2055, 'uncollectable': 0}, {'collections': 22, 'collected': 564, 'uncollectable': 0}, {'collections': 3, 'collected': 200, 'uncollectable': 0}]
